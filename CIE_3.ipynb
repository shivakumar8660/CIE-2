# %% [markdown]
# <a href="https://colab.research.google.com/github/shivakumar8660/CIE-2/blob/main/CIE_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['origin'] = le.fit_transform(df['origin'])
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       0  chevrolet chevelle malibu
# 1            70       0          buick skylark 320
# 2            70       0         plymouth satellite
# 3            70       0              amc rebel sst
# 4            70       0                ford torino
# ..          ...     ...                        ...
# 393          82       0            ford mustang gl
# 394          82       1                  vw pickup
# 395          82       0              dodge rampage
# 396          82       0                ford ranger
# 397          82       0                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.fillna(method='ffill',inplace=True)
# Out:
# /tmp/ipython-input-3337295870.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',inplace=True)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
x=df.iloc[:,1:8]
y=df[['mpg']]

# %%
x
# Out:
#      cylinders  displacement horsepower  weight  acceleration  model year  \
# 0            8         307.0        130    3504          12.0          70
# 1            8         350.0        165    3693          11.5          70
# 2            8         318.0        150    3436          11.0          70
# 3            8         304.0        150    3433          12.0          70
# 4            8         302.0        140    3449          10.5          70
# ..         ...           ...        ...     ...           ...         ...
# 393          4         140.0         86    2790          15.6          82
# 394          4          97.0         52    2130          24.6          82
# 395          4         135.0         84    2295          11.6          82
# 396          4         120.0         79    2625          18.6          82
# 397          4         119.0         82    2720          19.4          82
#
#      origin
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 393       0
# 394       1
# 395       0
# 396       0
# 397       0
#
# [398 rows x 7 columns]

# %%
y
# Out:
#       mpg
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# ..    ...
# 393  27.0
# 394  44.0
# 395  32.0
# 396  28.0
# 397  31.0
#
# [398 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      cylinders  displacement horsepower  weight  acceleration  model year  \
# 3            8         304.0        150    3433          12.0          70
# 18           4          97.0         88    2130          14.5          70
# 376          4          91.0         68    2025          18.2          82
# 248          4          91.0         60    1800          16.4          78
# 177          4         115.0         95    2694          15.0          75
# ..         ...           ...        ...     ...           ...         ...
# 71           3          70.0         97    2330          13.5          72
# 106          8         350.0        180    4499          12.5          73
# 270          4         134.0         95    2515          14.8          78
# 348          4          89.0         62    2050          17.3          81
# 102          4          97.0         46    1950          21.0          73
#
#      origin
# 3         0
# 18        2
# 376       2
# 248       2
# 177       1
# ..      ...
# 71        2
# 106       0
# 270       2
# 348       2
# 102       1
#
# [318 rows x 7 columns]

# %%
x_test
# Out:
#      cylinders  displacement horsepower  weight  acceleration  model year  \
# 198          4          91.0         53    1795          17.4          76
# 396          4         120.0         79    2625          18.6          82
# 33           6         232.0        100    2634          13.0          71
# 208          8         318.0        150    3940          13.2          76
# 93           8         318.0        150    4237          14.5          73
# ..         ...           ...        ...     ...           ...         ...
# 249          8         260.0        110    3365          15.5          78
# 225          6         250.0        110    3520          16.4          77
# 367          4         112.0         88    2605          19.6          82
# 175          4          90.0         70    1937          14.0          75
# 285          8         305.0        130    3840          15.4          79
#
#      origin
# 198       2
# 396       0
# 33        0
# 208       0
# 93        0
# ..      ...
# 249       0
# 225       0
# 367       0
# 175       1
# 285       0
#
# [80 rows x 7 columns]

# %%
y_train
# Out:
#       mpg
# 3    16.0
# 18   27.0
# 376  37.0
# 248  36.1
# 177  23.0
# ..    ...
# 71   19.0
# 106  12.0
# 270  21.1
# 348  37.7
# 102  26.0
#
# [318 rows x 1 columns]

# %%
y_test
# Out:
#       mpg
# 198  33.0
# 396  28.0
# 33   19.0
# 208  13.0
# 93   14.0
# ..    ...
# 249  19.9
# 225  17.5
# 367  28.0
# 175  29.0
# 285  17.0
#
# [80 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print("y_pred",y_pred)
# Out:
# y_pred [[32.88140046]
#  [29.55780381]
#  [21.36955005]
#  [16.79734409]
#  [12.4982001 ]
#  [27.20579297]
#  [27.90034172]
#  [ 9.77551057]
#  [16.88434148]
#  [22.03432001]
#  [12.80789558]
#  [36.15459303]
#  [25.17028795]
#  [13.69410403]
#  [23.9851906 ]
#  [ 6.38676545]
#  [29.53717565]
#  [23.57394424]
#  [16.32934475]
#  [36.28649078]
#  [23.71277029]
#  [18.98644465]
#  [28.71675729]
#  [28.74222236]
#  [14.9937939 ]
#  [34.66185682]
#  [25.48371184]
#  [24.95050273]
#  [21.94949529]
#  [ 8.78921085]
#  [28.43042198]
#  [34.85784604]
#  [20.52566418]
#  [26.07137821]
#  [34.25192799]
#  [11.98882056]
#  [22.93388155]
#  [21.74271783]
#  [12.32731516]
#  [26.75009008]
#  [26.24028149]
#  [27.42358817]
#  [20.15034925]
#  [ 7.2688964 ]
#  [24.53759706]
#  [34.94012278]
#  [26.75746176]
#  [24.19444148]
#  [22.51366966]
#  [27.5625466 ]
#  [22.68143886]
#  [33.67127815]
#  [32.67124307]
#  [10.95619387]
#  [27.70684405]
#  [10.00691734]
#  [19.76572214]
#  [29.87443683]
#  [23.17483434]
#  [20.47189168]
#  [16.18259662]
#  [32.09331845]
#  [24.02025492]
#  [20.49935146]
#  [20.92671853]
#  [25.51057393]
#  [25.11923146]
#  [32.38245245]
#  [28.07654777]
#  [12.71391714]
#  [31.2720768 ]
#  [13.02792301]
#  [10.04768517]
#  [19.42898455]
#  [27.39271123]
#  [22.12731743]
#  [20.51995099]
#  [29.52906034]
#  [29.33325802]
#  [20.0870444 ]]

# %%
import numpy as np
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)
rmse = np.sqrt(mse)
print("mse",mse)
print("mae",mae)
print("r2_score",r2)
print("rmse",rmse)
# Out:
# mse 8.197746885824987
# mae 2.255363261283571
# r2_score 0.8475304239212402
# rmse 2.8631707748272697
