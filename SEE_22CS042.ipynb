# %% [markdown]
# <a href="https://colab.research.google.com/github/shivakumar8660/CIE-2/blob/main/SEE_22CS042.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
from nltk import ngrams
nlp = spacy load("en_core_web_sm")
doc = nlp("I reside in Bengaluru")
grams = ngrams(doc.1)
print(list(grams))
# Out:
#   File "/tmp/ipython-input-1854285641.py", line 3
#     nlp = spacy load("en_core_web_sm")
#                 ^
# SyntaxError: invalid syntax

# %%
import spacy
from nltk import ngrams
nlp = spacy load("en_core_web_sm")
doc = nlp("I reside in Bengaluru")
grams = ngrams(doc,2)
print(list(grams))
# Out:
#   File "/tmp/ipython-input-3296861391.py", line 3
#     nlp = spacy load("en_core_web_sm")
#                 ^
# SyntaxError: invalid syntax
